# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:45b290a7-95fa-4db8-99cf-b3001726419b.png)

# %%
def sigmoid(x):
    return 1 / (1+np.exp(-x))

# %%
def tanh(x):
    return (np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))

# %%
forget_gate_calc = (1 * 0.943) + (1.3 * 1.4628) + 0.4389
forget_gate_calc
# Out:
# 3.28354

# %%
sigmoid(3.28354)
# Out:
# 0.9638597989840282

# %%
long_term_memory_remembered = 2 * 0.9638
long_term_memory_remembered
# Out:
# 1.9276

# %%
long_term_memory_add_percent = (1 * 1.2534) + (1.3 * 0.7841) - 0.995
long_term_memory_add_percent
# Out:
# 1.27773

# %%
sigmoid(1.27773)
# Out:
# 0.7820631244619662

# %%
long_term_memory_generate = (1 * 0.4562) + (1.3 * 0.9135) + 0.7524
long_term_memory_generate
# Out:
# 2.39615

# %%
tanh(2.39615)
# Out:
# 0.9835497068158935

# %%
long_term_memory_add = 0.7820 * 0.9835
long_term_memory_add
# Out:
# 0.769097

# %%
new_long_term_memory = 1.9276 + 0.769
new_long_term_memory
# Out:
# 2.6966

# %%
short_term_memory_to_add = (1 * 0.6583) + (1.3 * 0.9321) + 1.489
short_term_memory_to_add
# Out:
# 3.3590300000000006

# %%
sigmoid(3.359)
# Out:
# 0.966398319251531

# %%
tanh(2.6966)
# Out:
# 0.9909463737382164

# %%
new_short_term_memory = 0.9663 * 0.99
new_short_term_memory
# Out:
# 0.9566370000000001

# %% [markdown]
# ![image.png](attachment:0ff5a7b9-3b64-4807-b8d6-26334661fa72.png)
